# %%
l=["a","b","c","d","e","f"]
i=len(l)
while i>0:
      i-=1
      print(l[i])
# Out:
# f
# e
# d
# c
# b
# a

# %%
i=0
while i<3:
    j=0
    while j<3:
          print(j)
          j+=1
    i+=1
# Out:
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2

# %%
i=100
while i>=0:
    if i%2!=0:
       i-=1
       continue
    else:
         print(i)
         i-=1
# Out:
# 100
# 98
# 96
# 94
# 92
# 90
# 88
# 86
# 84
# 82
# 80
# 78
# 76
# 74
# 72
# 70
# 68
# 66
# 64
# 62
# 60
# 58
# 56
# 54
# 52
# 50
# 48
# 46
# 44
# 42
# 40
# 38
# 36
# 34
# 32
# 30
# 28
# 26
# 24
# 22
# 20
# 18
# 16
# 14
# 12
# 10
# 8
# 6
# 4
# 2
# 0

# %%
for i in range(100,-1,-1):
    if i%2!=0:
       continue
    else:
        print(i)
# Out:
# 100
# 98
# 96
# 94
# 92
# 90
# 88
# 86
# 84
# 82
# 80
# 78
# 76
# 74
# 72
# 70
# 68
# 66
# 64
# 62
# 60
# 58
# 56
# 54
# 52
# 50
# 48
# 46
# 44
# 42
# 40
# 38
# 36
# 34
# 32
# 30
# 28
# 26
# 24
# 22
# 20
# 18
# 16
# 14
# 12
# 10
# 8
# 6
# 4
# 2
# 0
